# %%
# !python Retrosynthesis/translate.py -model Model/USPTO-50K_model_step_500000.pt -src tmp/src10.txt -output tmp/tgt10.txt -verbose -batch_size 64 -replace_unk -max_length 200 -beam_size 3 -n_best 3
# Out:
# translating...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/velody/miniconda3/envs/flask_retro/lib/python3.6/site-packages/torchtext/data/field.py:359: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   var = torch.tensor(arr, dtype=self.dtype, device=device)
# _translate_batch
# /Users/velody/Desktop/KTV-Drug-Discovery/backend/Retrosynthesis/onmt/translate/translator.py:585: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(a, requires_grad=False)
# ...

# %%
import Retrosynthesis.results_visualize as rv

# %%
rv.draw_heat_map('tmp')

# %%
s = 'abc'
s = " ".join(list(s))
['<RX_'+ str(e) +'> ' + s for e in range(1,11)]
# Out:
# ['<RX_1> a b c',
#  '<RX_2> a b c',
#  '<RX_3> a b c',
#  '<RX_4> a b c',
#  '<RX_5> a b c',
#  '<RX_6> a b c',
#  '<RX_7> a b c',
#  '<RX_8> a b c',
#  '<RX_9> a b c',
#  '<RX_10> a b c']

# %%
'N C C 1 = C C [ C @ @ H ] ( c 2 c c c ( C l ) c c 2 C l ) [ C @ H ] ( [ N + ] ( = O ) [ O - ] ) C 1'.replace(" ","")
# Out:
# 'NCC1=CC[C@@H](c2ccc(Cl)cc2Cl)[C@H]([N+](=O)[O-])C1'

# %%
import os
print(os.listdir('tmp'))
# Out:
# ['tgt10.txt', 'heatmap_tmp3.png', 'heatmap_tmp2.png', 'heatmap_tmp0.png', 'heatmap_tmp1.png', 'heatmap_tmp5.png', 'heatmap_tmp4.png', 'heatmap_tmp6.png', 'heatmap_tmp7.png', 'result.pkl', 'heatmap_tmp9.png', 'heatmap_tmp8.png', 'src10.txt']
